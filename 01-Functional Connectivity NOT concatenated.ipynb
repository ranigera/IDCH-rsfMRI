# %% [markdown]
# # Import stuff

# %%
import os
import numpy as np
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Params

# %%
#dirs:
pre_proc_dir = 'data/pre_proc_data'
masks_dir = 'masks'
connectiviity_data_dir = 'data/connectivity_data'
time_series_dir = 'data/time_series'

# file_format:
any_session_file_format = '_space-MNI152NLin6Asym_desc-smoothAROMAnonaggr_bold.nii.gz'

# R01 to IDCH mapping:
mapping_R01_to_IDCH = {'222': '101', '183': '102', '216': '103', '192': '104', '251': '105', '206': '106', '180': '107', '184': '108', '169': '109', '207': '110',
                       '159': '111', '115': '112', '114': '113', '232': '114', '173': '115', '171': '117', '215': '118', '265': '119', '177': '120', '269': '121',
                       '261': '122'}

# masks: * mask files should end with _mask.nii.gz
masks_to_apply = ['L_SMA_mask.nii.gz', 'R_SMA_mask.nii.gz', 'L_post_putamen_mask.nii.gz', 'R_post_putamen_mask.nii.gz', 'R_premotor_mask.nii.gz', 'L_premotor_mask.nii.gz', 'L_anterior_caudate_mask.nii.gz', 'R_anterior_caudate_mask.nii.gz', 'vmpfc_mask.nii.gz', 'L_vlpfc_mask.nii.gz', 'R_vlpfc_mask.nii.gz', 'L_anterior_putamen_mask.nii.gz', 'R_anterior_putamen_mask.nii.gz', 'R_frontopolar_mask.nii.gz']

# regions to test connectivity between: * add pairs of regions to test connectivity between
connectivity_regions = [['L_SMA', 'L_post_putamen'], ['R_SMA', 'R_post_putamen'], ['L_premotor', 'L_post_putamen'], ['R_premotor', 'R_post_putamen'], ['L_anterior_caudate', 'vmpfc'], ['R_anterior_caudate', 'vmpfc'], ['L_vlpfc', 'L_post_putamen'], ['R_vlpfc', 'R_post_putamen'], ['L_vlpfc', 'L_anterior_putamen'], ['R_vlpfc', 'R_anterior_putamen'], ['L_vlpfc', 'L_anterior_caudate'], ['R_vlpfc', 'R_anterior_caudate'], ['R_frontopolar', 'R_anterior_caudate'], ['R_frontopolar', 'R_post_putamen'], ['R_post_putamen', 'L_post_putamen'], ['R_anterior_caudate', 'L_anterior_caudate']]

# %% [markdown]
# # Create IDCH sub id folders + Extract time series using masks (directly from the data) for each session separately

# %%
# get all directories in the root directory
r01_sub_dirs = os.listdir(pre_proc_dir)
r01_sub_dirs = [x for x in r01_sub_dirs if 'MBMFHab' in x]

for dir in r01_sub_dirs:
    sub_dir = os.path.join(pre_proc_dir, dir, 'func')
    
    # get sub R01 id:
    sub_R01_id = dir.split('Hab0')[1][:3]
    # get sub IDCH id:
    sub_IDCH_id = mapping_R01_to_IDCH[sub_R01_id]

    # create a new foler for the sub according to sub_IDCH_id:
    sub_IDCH_dir = os.path.join(time_series_dir, 'sub-' + sub_IDCH_id)
    if not os.path.exists(sub_IDCH_dir):
        os.makedirs(sub_IDCH_dir)

    for mask in masks_to_apply:
        mask_name = mask.split('_mask')[0]
        for session in ['1', '2']:
            input_file = [f for f in os.listdir(sub_dir) if f'{session}{any_session_file_format}' in f][0]
            if not os.path.exists(os.path.join(sub_IDCH_dir, f"sub-{sub_IDCH_id}_IDCH_ses-{session}_{mask_name}_time_series.txt")):
                print(f'>> Extracting time series for sub-{sub_IDCH_id}, session {session}, using {mask}')
                # fslmeants -i <input_file> -o <output_file> -m <mask_file>
                os.system(f'fslmeants -i {os.path.join(sub_dir, input_file)} -o {os.path.join(sub_IDCH_dir, f"sub-{sub_IDCH_id}_IDCH_ses-{session}_{mask_name}_time_series.txt")} -m {os.path.join(masks_dir, mask)}')

# %% [markdown]
# # Calculate correlations (connectivity) and plot each subject's timeseries data

# %%
# get sub dirs:
IDCH_sub_dirs = [x for x in os.listdir(time_series_dir) if 'sub-' in x]
# sort the sub dirs:
IDCH_sub_dirs.sort()

# List to collect data for DataFrame
per_region_data = {}

# Loop over the subject directories in the root directory
for region_pair in connectivity_regions:
    print(f"Analyzing connectivity between {region_pair[0]} and {region_pair[1]}")
    region_df = []
    for subj in IDCH_sub_dirs:
        subject_dir = os.path.join(time_series_dir, subj)
        sub_ID = subj.split('-')[1]
        print(f"Analyzing subject {sub_ID}")

        # Get the data for both regions:
        reg1_ses1_dir = os.path.join(subject_dir, f'sub-{sub_ID}_IDCH_ses-1_{region_pair[0]}_time_series.txt')
        reg1_ses2_dir = os.path.join(subject_dir, f'sub-{sub_ID}_IDCH_ses-2_{region_pair[0]}_time_series.txt')
        reg2_ses1_dir = os.path.join(subject_dir, f'sub-{sub_ID}_IDCH_ses-1_{region_pair[1]}_time_series.txt')
        reg2_ses2_dir = os.path.join(subject_dir, f'sub-{sub_ID}_IDCH_ses-2_{region_pair[1]}_time_series.txt')

        reg1_ses1_ts_data = np.loadtxt(reg1_ses1_dir)
        reg1_ses2_ts_data = np.loadtxt(reg1_ses2_dir)
        reg2_ses1_ts_data = np.loadtxt(reg2_ses1_dir)
        reg2_ses2_ts_data = np.loadtxt(reg2_ses2_dir)

        # Calculate the Pearson correlation between the time series
        correlation_ses1, p_val_ses_1 = pearsonr(reg1_ses1_ts_data, reg2_ses1_ts_data)
        z_score_ses1 = 0.5 * np.log((1 + correlation_ses1) / (1 - correlation_ses1))
        correlation_ses2, p_val_ses_2 = pearsonr(reg1_ses2_ts_data, reg2_ses2_ts_data)
        z_score_ses2 = 0.5 * np.log((1 + correlation_ses2) / (1 - correlation_ses2))

        # Print correlation for the subject:
        print(f">> Subject {sub_ID}: correlation between {region_pair[0]} and {region_pair[1]}:\n - session 1: r={correlation_ses1}, p={p_val_ses_1}, z-score={z_score_ses1}\n - session 2: r={correlation_ses2}, p={p_val_ses_2}, z-score={z_score_ses2}")

        # # Scatterplot
        # fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
        # axs[0].scatter(reg1_ses1_ts_data, reg2_ses1_ts_data)
        # axs[0].set_title(f'Scatterplot for Subject {sub_ID} - Session 1')
        # axs[0].set_xlabel(region_pair[0])
        # axs[0].set_ylabel(region_pair[1])
        # axs[1].scatter(reg1_ses2_ts_data, reg2_ses2_ts_data)
        # axs[1].set_title(f'Scatterplot for Subject {sub_ID} - Session 2')
        # axs[1].set_xlabel(region_pair[0])
        # axs[1].set_ylabel(region_pair[1])
        # plt.show()

        # # Line Plot for the Time-Series Data
        # fig, axs = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
        # axs[0].plot(reg1_ses1_ts_data, color='red', label=region_pair[0])
        # axs[0].plot(reg2_ses1_ts_data, color='blue', label=region_pair[1])
        # axs[0].set_title(f'Time Series for Subject {sub_ID} - Session 1')
        # axs[0].set_xlabel('Time')
        # axs[0].set_ylabel('BOLD Signal')
        # axs[0].legend()
        # axs[1].plot(reg1_ses2_ts_data, color='red', label=region_pair[0])
        # axs[1].plot(reg2_ses2_ts_data, color='blue', label=region_pair[1])
        # axs[1].set_title(f'Time Series for Subject {sub_ID} - Session 2')
        # axs[1].set_xlabel('Time')
        # axs[1].set_ylabel('BOLD Signal')
        # axs[1].legend()
        # plt.show()

        #Append the data to list (with means)
        region_df.append({"subID": sub_ID, "corr": np.mean([correlation_ses1, correlation_ses2]), "p_val": np.mean([p_val_ses_1, p_val_ses_2]), "z_score": np.mean([z_score_ses1, z_score_ses2])})

    # keep data
    region_connectivity_df = pd.DataFrame(region_df)
    per_region_data[region_pair[0] + "_" + region_pair[1]] = region_connectivity_df

    # save region_connectivity_df to csv
    region_connectivity_df.to_csv(f'{connectiviity_data_dir}/{region_pair[0]}_{region_pair[1]}_connectivity.csv', index=False)

    # # Plot the histogram of the Z-scores
    # plt.hist(region_connectivity_df.z_score, alpha=0.6, color='g')
    # plt.title("Histogram of Z-scores")
    # plt.show()

    # display(region_connectivity_df)


# create a data frame that has only the connectivity score (z-score) for each region pair (and the subject ID):\
connectivity_df = pd.DataFrame(columns=['subID'])
for key in per_region_data.keys():
    connectivity_score = per_region_data[key][['subID', 'z_score']]
    connectivity_score = connectivity_score.rename(columns={'z_score': key})
    connectivity_df = pd.merge(connectivity_df, connectivity_score, on='subID', how='outer')
# save the connectivity_df to csv
connectivity_df.to_csv(f'{connectiviity_data_dir}/all_connectivity_scores.csv', index=False)
display(connectivity_df)
# Out:
# Analyzing connectivity between L_SMA and L_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.6974700840156763, p=1.3479936196041346e-88, z-score=0.8623570336628756
#  - session 2: r=0.6967995325622821, p=2.3243244018746332e-88, z-score=0.8610524661601807
# Analyzing subject 102
# >> Subject 102: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.5241229811376744, p=1.2189686019082915e-43, z-score=0.5820074860801172
#  - session 2: r=0.7776485740091901, p=1.2331480612295025e-122, z-score=1.039393806958802
# Analyzing subject 103
# >> Subject 103: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.8375730162730388, p=3.8548754227928483e-159, z-score=1.21298619858267
#  - session 2: r=0.4888643257896711, p=2.2800702537756377e-37, z-score=0.5345669243194686
# Analyzing subject 104
# >> Subject 104: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.6770083862472944, p=1.1646095530647916e-81, z-score=0.8235702016413945
#  - session 2: r=0.5259928793547737, p=5.400453824657053e-44, z-score=0.5845891007886235
# Analyzing subject 105
# >> Subject 105: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.37216825264957903, p=3.786330964923215e-21, z-score=0.39093761077681755
#  - session 2: r=0.49951098801742666, p=3.472385654993435e-39, z-score=0.5486543407581271
# Analyzing subject 106
# >> Subject 106: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.49577732777442074, p=1.5319100841347687e-38, z-score=0.5436916609559269
#  - session 2: r=0.599815884646723, p=6.710218038839511e-60, z-score=0.6928595499599005
# Analyzing subject 107
# >> Subject 107: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.6976653778578822, p=1.1498824160442043e-88, z-score=0.8627374273699312
#  - session 2: r=0.6937274618767372, p=2.7667296820044446e-87, z-score=0.8551058124377585
# Analyzing subject 108
# >> Subject 108: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.5106993785289443, p=3.6358528383289216e-41, z-score=0.5636754593765279
#  - session 2: r=0.7950433842523501, p=5.860398614322851e-132, z-score=1.0849930719439864
# Analyzing subject 109
# >> Subject 109: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.481506242405304, p=3.776576429487149e-36, z-score=0.5249432961665185
#  - session 2: r=0.6472283976384994, p=1.6268072532391866e-72, z-score=0.7705142833951442
# Analyzing subject 110
# >> Subject 110: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.6910938950264321, p=2.2560694110214767e-86, z-score=0.8500467551836176
#  - session 2: r=0.7670438119902517, p=2.3444004117885216e-117, z-score=1.0131064324908758
# Analyzing subject 111
# >> Subject 111: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.7436502268646181, p=1.1991022335459222e-106, z-score=0.9585966065573367
#  - session 2: r=0.6264761512726176, p=1.0037710193455716e-66, z-score=0.7355946143259321
# Analyzing subject 112
# >> Subject 112: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.462094078675433, p=4.51712882029062e-33, z-score=0.49997065504718025
#  - session 2: r=0.1476290357397365, p=0.0002850535343990697, z-score=0.14871577446465692
# Analyzing subject 113
# >> Subject 113: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.702276196421076, p=2.5965172190604533e-90, z-score=0.8717776752170836
#  - session 2: r=0.3365483755903402, p=2.3510199625518388e-17, z-score=0.350194894622111
# Analyzing subject 114
# >> Subject 114: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.3927211498299782, p=1.458433334771007e-23, z-score=0.4150133489267866
#  - session 2: r=0.6180555673268253, p=1.6916414642958294e-64, z-score=0.7218526532137511
# Analyzing subject 115
# >> Subject 115: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.7242587174058053, p=1.279448607003829e-98, z-score=0.9165447319352348
#  - session 2: r=0.6283164929013494, p=3.205149523283839e-67, z-score=0.7386296144241052
# Analyzing subject 117
# >> Subject 117: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.8018412230056401, p=7.501328637156913e-136, z-score=1.103747854696708
#  - session 2: r=0.38366931030909524, p=1.771488435977462e-22, z-score=0.4043552582929912
# Analyzing subject 118
# >> Subject 118: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.3853155456498201, p=1.1313962084011308e-22, z-score=0.40628708484437276
#  - session 2: r=0.6961964282289567, p=3.7891942090630496e-88, z-score=0.8598811405511777
# Analyzing subject 119
# >> Subject 119: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.47438046793429156, p=5.368603168017638e-35, z-score=0.5157077654281251
#  - session 2: r=0.8080180976772008, p=1.5997753294144104e-139, z-score=1.1212927209147552
# Analyzing subject 120
# >> Subject 120: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.761343187920927, p=1.2388879741333911e-114, z-score=0.9994026923243772
#  - session 2: r=0.417614266170018, p=1.0072633453667118e-26, z-score=0.4447988211547371
# Analyzing subject 121
# >> Subject 121: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.7847513916900375, p=2.4498066533084097e-126, z-score=1.0576203651608826
#  - session 2: r=0.6460597550547209, p=3.5433848591196767e-72, z-score=0.7685057922372878
# Analyzing subject 122
# >> Subject 122: correlation between L_SMA and L_post_putamen:
#  - session 1: r=0.6539077031370997, p=1.7790392866138773e-74, z-score=0.7820952891939138
#  - session 2: r=0.4552136561646487, p=5.002710349007135e-32, z-score=0.491257161705239
# Analyzing connectivity between R_SMA and R_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.7634788625923132, p=1.207589852574814e-115, z-score=1.0045030918401137
#  - session 2: r=0.759369339309046, p=1.0425859563236681e-113, z-score=0.9947237320819411
# Analyzing subject 102
# >> Subject 102: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6393946145820969, p=2.8157655546612668e-70, z-score=0.7571490349797184
#  - session 2: r=0.6406378177293184, p=1.2552885340243352e-70, z-score=0.7592548071350954
# Analyzing subject 103
# >> Subject 103: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.7846938890748386, p=2.6282392181096737e-126, z-score=1.057470700761256
#  - session 2: r=0.8132377364829652, p=9.913795919009638e-143, z-score=1.1365164204937208
# Analyzing subject 104
# >> Subject 104: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6510906927366829, p=1.2115739710857257e-73, z-score=0.7771896752787509
#  - session 2: r=0.4455250066250711, p=1.3490403774401352e-30, z-score=0.47910307639035554
# Analyzing subject 105
# >> Subject 105: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.38893841722214395, p=4.180034268081441e-23, z-score=0.41054863074094955
#  - session 2: r=0.337634400026034, p=1.830757025607066e-17, z-score=0.35142014520324566
# Analyzing subject 106
# >> Subject 106: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.5695609122560535, p=6.817832190672382e-53, z-score=0.6468726817656109
#  - session 2: r=0.5360137005575407, p=6.304175758203218e-46, z-score=0.5985454042874979
# Analyzing subject 107
# >> Subject 107: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6634305167859113, p=2.325076967602003e-77, z-score=0.7989163547603951
#  - session 2: r=0.5851661718349654, p=2.048748335785814e-56, z-score=0.6702832475535124
# Analyzing subject 108
# >> Subject 108: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6841748304122263, p=5.032241208025048e-84, z-score=0.8369211041322894
#  - session 2: r=0.7992837614222315, p=2.276499572908147e-134, z-score=1.0966258960709
# Analyzing subject 109
# >> Subject 109: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.5101240264676843, p=4.615582182413579e-41, z-score=0.5628974096720338
#  - session 2: r=0.7278378314576673, p=4.760175831704193e-100, z-score=0.9241140004565285
# Analyzing subject 110
# >> Subject 110: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.7579312133127855, p=4.8585216355408904e-113, z-score=0.991335510697297
#  - session 2: r=0.696061985408837, p=4.224635279930615e-88, z-score=0.8596202912198678
# Analyzing subject 111
# >> Subject 111: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6462369804554168, p=3.1495126169314046e-72, z-score=0.7688100458862668
#  - session 2: r=0.8154887731961646, p=3.815214363957115e-144, z-score=1.1431998477286867
# Analyzing subject 112
# >> Subject 112: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.3577896114399163, p=1.4703290273043622e-19, z-score=0.3743487063857885
#  - session 2: r=0.4382124110716577, p=1.5131633028933003e-29, z-score=0.47001620870548444
# Analyzing subject 113
# >> Subject 113: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6419528577307606, p=5.319196472756925e-71, z-score=0.7614884596394883
#  - session 2: r=0.2190450639434042, p=5.9513169999605646e-08, z-score=0.22265282444740309
# Analyzing subject 114
# >> Subject 114: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.60155751881879, p=2.5142493254883064e-60, z-score=0.6955843672491535
#  - session 2: r=0.706136465409205, p=1.0267719470196635e-91, z-score=0.8794356123895118
# Analyzing subject 115
# >> Subject 115: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6006057050968459, p=4.302531306801841e-60, z-score=0.6940941327820817
#  - session 2: r=0.6084214442874629, p=4.947526956318401e-62, z-score=0.7064111795767993
# Analyzing subject 117
# >> Subject 117: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6617272492958022, p=7.762556968051901e-77, z-score=0.7958801636006632
#  - session 2: r=0.8971125314857928, p=2.550365462488205e-214, z-score=1.4572262183302975
# Analyzing subject 118
# >> Subject 118: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6983813476533329, p=6.413379697361271e-89, z-score=0.8641337245757867
#  - session 2: r=0.4326139973410331, p=9.258761755591426e-29, z-score=0.46310808595647907
# Analyzing subject 119
# >> Subject 119: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.9154691958178939, p=1.3470574151615262e-238, z-score=1.5603009340047311
#  - session 2: r=0.8160987067841391, p=1.5662046009436633e-144, z-score=1.1450233739428444
# Analyzing subject 120
# >> Subject 120: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.45436717627984485, p=6.699664216059102e-32, z-score=0.49018994455350084
#  - session 2: r=0.3135291983730148, p=3.75149557176015e-15, z-score=0.32445457312177267
# Analyzing subject 121
# >> Subject 121: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.83296847013733, p=7.808059156630725e-156, z-score=1.1977547251442493
#  - session 2: r=0.6660832742220665, p=3.500296896778393e-78, z-score=0.8036695840662583
# Analyzing subject 122
# >> Subject 122: correlation between R_SMA and R_post_putamen:
#  - session 1: r=0.6120712186434357, p=5.890303061384243e-63, z-score=0.7122266664099799
#  - session 2: r=0.6031343548949494, p=1.0283750199288605e-60, z-score=0.6980590828869324
# Analyzing connectivity between L_premotor and L_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.64620012517297, p=3.22766428123897e-72, z-score=0.7687467643231432
#  - session 2: r=0.6851450635885572, p=2.3790470432758695e-84, z-score=0.8387474584030117
# Analyzing subject 102
# >> Subject 102: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.5247201025306885, p=9.404322001440646e-44, z-score=0.5828311222757115
#  - session 2: r=0.7842028052261064, p=4.786756181939315e-126, z-score=1.056193966596495
# Analyzing subject 103
# >> Subject 103: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.8480465090563409, p=4.606340955653143e-167, z-score=1.2491549628661953
#  - session 2: r=0.5775978595926186, p=1.1049725562636468e-54, z-score=0.6588504137334065
# Analyzing subject 104
# >> Subject 104: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.5659103223571312, p=4.272623542071575e-52, z-score=0.6414857331126683
#  - session 2: r=0.4296236241806539, p=2.403084625477214e-28, z-score=0.4594350186806194
# Analyzing subject 105
# >> Subject 105: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.403737682655808, p=6.2797347604470895e-25, z-score=0.4281065157028835
#  - session 2: r=0.4767836090060086, p=2.208630883535587e-35, z-score=0.5188133183442661
# Analyzing subject 106
# >> Subject 106: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.5452155818980405, p=9.262898315427533e-48, z-score=0.6115476072534385
#  - session 2: r=0.5845607002149129, p=2.829539928593026e-56, z-score=0.6693629865453741
# Analyzing subject 107
# >> Subject 107: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.7101199726581909, p=3.4640524674123733e-93, z-score=0.8874258339613376
#  - session 2: r=0.7362038132121473, p=1.7607466041850382e-103, z-score=0.9421397535052086
# Analyzing subject 108
# >> Subject 108: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.6113392881311828, p=9.045963113201015e-63, z-score=0.7110571055637289
#  - session 2: r=0.845327287440476, p=5.98052112685971e-165, z-score=1.2395502898452955
# Analyzing subject 109
# >> Subject 109: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.3979244850772776, p=3.350501643461789e-24, z-score=0.42118051371258985
#  - session 2: r=0.6756142940963742, p=3.2987179012775307e-81, z-score=0.8210009308407762
# Analyzing subject 110
# >> Subject 110: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.6600481855877243, p=2.5280108132321407e-76, z-score=0.7928990115709851
#  - session 2: r=0.7595571299766545, p=8.520903418355218e-114, z-score=0.9951674555130706
# Analyzing subject 111
# >> Subject 111: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.8178995373149851, p=1.1085315820731909e-145, z-score=1.1504392428240722
#  - session 2: r=0.7289050030750307, p=1.7660307635148289e-100, z-score=0.9263871196423498
# Analyzing subject 112
# >> Subject 112: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.5372203282675247, p=3.65171256452758e-46, z-score=0.600240006492736
#  - session 2: r=0.13975698110469456, p=0.0005968174608834707, z-score=0.14067770737696703
# Analyzing subject 113
# >> Subject 113: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.7002891379726937, p=1.341946752700639e-89, z-score=0.8678676900380052
#  - session 2: r=0.34422019778642854, p=3.9323390965235055e-18, z-score=0.3588721400320277
# Analyzing subject 114
# >> Subject 114: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.5637631368456097, p=1.2441645073403854e-51, z-score=0.6383325513281266
#  - session 2: r=0.6060220140549564, p=1.9746617283139748e-61, z-score=0.7026102836466959
# Analyzing subject 115
# >> Subject 115: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.735470597350616, p=3.562071496683533e-103, z-score=0.9405407425064387
#  - session 2: r=0.5722170077928775, p=1.7678198587231453e-53, z-score=0.6508129848425425
# Analyzing subject 117
# >> Subject 117: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.856969166873047, p=2.668426789495165e-174, z-score=1.2818203670971098
#  - session 2: r=0.7798678448271193, p=8.896586191052132e-124, z-score=1.0450331623591576
# Analyzing subject 118
# >> Subject 118: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.35184699223430194, p=6.324006460985957e-19, z-score=0.3675501435996953
#  - session 2: r=0.6259107864450143, p=1.4232343213983184e-66, z-score=0.734664556915903
# Analyzing subject 119
# >> Subject 119: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.7662325278986669, p=5.784896323048872e-117, z-score=1.0111385647075535
#  - session 2: r=0.8401699829299383, p=4.732708874061724e-161, z-score=1.2217511855906482
# Analyzing subject 120
# >> Subject 120: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.8339105779140887, p=1.6760642759326795e-156, z-score=1.2008397815467367
#  - session 2: r=0.30357336311850364, p=2.94800880401506e-14, z-score=0.3134510284343993
# Analyzing subject 121
# >> Subject 121: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.7971075269482316, p=3.996099540869266e-133, z-score=1.090628786304212
#  - session 2: r=0.6104607805134673, p=1.5116161156430826e-62, z-score=0.7096555319941021
# Analyzing subject 122
# >> Subject 122: correlation between L_premotor and L_post_putamen:
#  - session 1: r=0.6053859464351482, p=2.8443475657490202e-61, z-score=0.7016056320303016
#  - session 2: r=0.4057540689341111, p=3.4861083042427e-25, z-score=0.43051794131014437
# Analyzing connectivity between R_premotor and R_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.8154553264174127, p=4.005725223380992e-144, z-score=1.1431000081881106
#  - session 2: r=0.7798737610195887, p=8.83408928103273e-124, z-score=1.0450482623319892
# Analyzing subject 102
# >> Subject 102: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.7411393399155762, p=1.4417544243831362e-105, z-score=0.9530025230010783
#  - session 2: r=0.7211250974564741, p=2.1881172863450588e-97, z-score=0.9099850895492663
# Analyzing subject 103
# >> Subject 103: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.7681563305010485, p=6.753231535871527e-118, z-score=1.0158146776745316
#  - session 2: r=0.7793879531956595, p=1.5748848965150576e-123, z-score=1.0438095115212582
# Analyzing subject 104
# >> Subject 104: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.5926738727697153, p=3.531290142800651e-58, z-score=0.6817777018882072
#  - session 2: r=0.4885611305621693, p=2.5631351389968424e-37, z-score=0.5341685911353313
# Analyzing subject 105
# >> Subject 105: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.5890013556034037, p=2.608386819393298e-57, z-score=0.6761355517339921
#  - session 2: r=0.30748330575814464, p=1.3242317552490664e-14, z-score=0.31776354140779306
# Analyzing subject 106
# >> Subject 106: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.49668991365982107, p=1.0676083074387085e-38, z-score=0.5449023852322781
#  - session 2: r=0.2372353046281998, p=4.025892875266101e-09, z-score=0.24184249330046706
# Analyzing subject 107
# >> Subject 107: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.7362387788611441, p=1.7024660110195041e-103, z-score=0.9422161013505697
#  - session 2: r=0.6093315962114919, p=2.9176352250578674e-62, z-score=0.7078575430637646
# Analyzing subject 108
# >> Subject 108: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.7495671798859719, p=3.0406961171325584e-109, z-score=0.9719665045841013
#  - session 2: r=0.8465477932229213, p=6.811524700351047e-166, z-score=1.2438419775278389
# Analyzing subject 109
# >> Subject 109: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.6911737876014168, p=2.117622743498077e-86, z-score=0.8501997082238476
#  - session 2: r=0.7312834902668484, p=1.9045546212192214e-101, z-score=0.9314806787883205
# Analyzing subject 110
# >> Subject 110: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.825714267874532, p=7.97883939916323e-151, z-score=1.1745152390368012
#  - session 2: r=0.8084006326846553, p=9.382658339629123e-140, z-score=1.1223957709299306
# Analyzing subject 111
# >> Subject 111: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.8357102865284991, p=8.629383204647678e-158, z-score=1.206777673922594
#  - session 2: r=0.9324372465868418, p=1.4848716014258556e-266, z-score=1.6767402305435355
# Analyzing subject 112
# >> Subject 112: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.5542298005716889, p=1.3042271455280811e-49, z-score=0.6244659127474982
#  - session 2: r=0.4487038133088125, p=4.630582152292147e-31, z-score=0.4830761525700605
# Analyzing subject 113
# >> Subject 113: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.3937074096203955, p=1.105811320958648e-23, z-score=0.4161799923324781
#  - session 2: r=0.41357813788357034, p=3.4187875867171265e-26, z-score=0.4399200117651583
# Analyzing subject 114
# >> Subject 114: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.5651339393944708, p=6.2940087945801414e-52, z-score=0.6403443032840018
#  - session 2: r=0.7461935914550444, p=9.373014672920056e-108, z-score=0.9643109010197574
# Analyzing subject 115
# >> Subject 115: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.7645400242425141, p=3.762952103385973e-116, z-score=1.0070521906082848
#  - session 2: r=0.6403071028191836, p=1.556808886667929e-70, z-score=0.7586940785531806
# Analyzing subject 117
# >> Subject 117: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.775384065797664, p=1.748007220734849e-121, z-score=1.0336900345060285
#  - session 2: r=0.8982563029951112, p=1.0781561159589116e-215, z-score=1.4631170660029422
# Analyzing subject 118
# >> Subject 118: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.706717652314603, p=6.28453680575087e-92, z-score=0.8805957571672796
#  - session 2: r=0.4165820978086374, p=1.378968812439997e-26, z-score=0.443549266438624
# Analyzing subject 119
# >> Subject 119: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.9597722261833953, p=0.0, z-score=1.9430129431553014
#  - session 2: r=0.843703183725124, p=1.0462265521547713e-163, z-score=1.2338872799952443
# Analyzing subject 120
# >> Subject 120: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.8820170818094851, p=1.4259039806487668e-197, z-score=1.3847797718139083
#  - session 2: r=0.6285359614867718, p=2.795767022870785e-67, z-score=0.7389923241776516
# Analyzing subject 121
# >> Subject 121: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.8161103204211861, p=1.5398272620544425e-144, z-score=1.1450581480783144
#  - session 2: r=0.7093515617480434, p=6.690387318006146e-93, z-score=0.8858774765431346
# Analyzing subject 122
# >> Subject 122: correlation between R_premotor and R_post_putamen:
#  - session 1: r=0.6052383904356051, p=3.0952684773909567e-61, z-score=0.7013727458908218
#  - session 2: r=0.6816335129233777, p=3.5316520488041926e-83, z-score=0.8321588674191586
# Analyzing connectivity between L_anterior_caudate and vmpfc
# Analyzing subject 101
# >> Subject 101: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.06314207547153933, p=0.12235223878618949, z-score=0.06322619095069323
#  - session 2: r=0.2605502979654503, p=9.104702835480005e-11, z-score=0.26669869268013796
# Analyzing subject 102
# >> Subject 102: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.3252656593253245, p=2.982255794541036e-16, z-score=0.3375245859472278
#  - session 2: r=0.5638057297066933, p=1.2181562461207475e-51, z-score=0.6383949907349813
# Analyzing subject 103
# >> Subject 103: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.6835944506366773, p=7.866468151783381e-84, z-score=0.8358307829734979
#  - session 2: r=0.70501011773557, p=2.649557767997782e-91, z-score=0.8771926327564156
# Analyzing subject 104
# >> Subject 104: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.1998551779120138, p=8.011107803989081e-07, z-score=0.20258170226267555
#  - session 2: r=0.2615639478197795, p=7.65426740991126e-11, z-score=0.26778647598027844
# Analyzing subject 105
# >> Subject 105: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.29086407205376946, p=3.6610094185145875e-13, z-score=0.29950993521419356
#  - session 2: r=0.4982109956981788, p=5.834064564903544e-39, z-score=0.5469236422892537
# Analyzing subject 106
# >> Subject 106: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.3048593014433259, p=2.268787750997447e-14, z-score=0.31486811495808403
#  - session 2: r=0.4499905114260376, p=2.9940996110972334e-31, z-score=0.48468838075936743
# Analyzing subject 107
# >> Subject 107: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.05356189726432484, p=0.19012891147325897, z-score=0.053613206441981975
#  - session 2: r=0.4715512216584226, p=1.5138738123794258e-34, z-score=0.5120632472689121
# Analyzing subject 108
# >> Subject 108: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.8160978251261657, p=1.5682253358382433e-144, z-score=1.1450207341188536
#  - session 2: r=0.6279426945989427, p=4.044072916408247e-67, z-score=0.7380122284394801
# Analyzing subject 109
# >> Subject 109: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.4057376586027494, p=3.502903190539319e-25, z-score=0.4304982969303052
#  - session 2: r=0.213102930394648, p=1.366484783181901e-07, z-score=0.21641965491914697
# Analyzing subject 110
# >> Subject 110: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.43243228584524956, p=9.813888320210714e-29, z-score=0.4628845576108116
#  - session 2: r=0.6145977430883933, p=1.3281048614491794e-63, z-score=0.7162767585791174
# Analyzing subject 111
# >> Subject 111: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.6205248123847019, p=3.822804441199911e-65, z-score=0.7258580605525558
#  - session 2: r=0.5747185462989233, p=4.902682187502921e-54, z-score=0.6545403203940529
# Analyzing subject 112
# >> Subject 112: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.36094375129005224, p=6.693644457684796e-20, z-score=0.3779705980935882
#  - session 2: r=0.0727459296015318, p=0.0749863462375939, z-score=0.07287466169625516
# Analyzing subject 113
# >> Subject 113: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.23636450346717677, p=4.603732259863727e-09, z-score=0.24091996185980727
#  - session 2: r=0.3078043939086183, p=1.2393373009897368e-14, z-score=0.31811819572791733
# Analyzing subject 114
# >> Subject 114: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.519072972700651, p=1.0713393161874791e-42, z-score=0.5750699966013044
#  - session 2: r=0.3547081749832235, p=3.1449771992819515e-19, z-score=0.37081934237060704
# Analyzing subject 115
# >> Subject 115: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.5102547743186026, p=4.37216268333055e-41, z-score=0.5630741659973981
#  - session 2: r=0.5437778513552647, p=1.8066303120859416e-47, z-score=0.6095039913050876
# Analyzing subject 117
# >> Subject 117: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.6826904755521639, p=1.5742540352875115e-83, z-score=0.8341357748204868
#  - session 2: r=0.4636516942233834, p=2.6008958438452043e-33, z-score=0.5019529890984317
# Analyzing subject 118
# >> Subject 118: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.362431627575862, p=4.603870796848987e-20, z-score=0.37968241076977566
#  - session 2: r=0.3769618592647963, p=1.0724371704141456e-21, z-score=0.3965135309599219
# Analyzing subject 119
# >> Subject 119: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.4962343216543522, p=1.2786782766342116e-38, z-score=0.5442977711737087
#  - session 2: r=0.7129292576288395, p=3.0650923152868965e-94, z-score=0.8931157628154359
# Analyzing subject 120
# >> Subject 120: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.23582624097262309, p=5.000348176188624e-09, z-score=0.24034992490416904
#  - session 2: r=0.3246079228623595, p=3.4471157246321965e-16, z-score=0.33678920504857934
# Analyzing subject 121
# >> Subject 121: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.025847869981078783, p=0.5274351030705811, z-score=0.02585362871707715
#  - session 2: r=0.2700089808324853, p=1.7516017204708098e-11, z-score=0.27687350969638463
# Analyzing subject 122
# >> Subject 122: correlation between L_anterior_caudate and vmpfc:
#  - session 1: r=0.4846823994096324, p=1.1336438148520167e-36, z-score=0.5290863725768005
#  - session 2: r=0.3759763223977624, p=1.3923653350046243e-21, z-score=0.3953652491302757
# Analyzing connectivity between R_anterior_caudate and vmpfc
# Analyzing subject 101
# >> Subject 101: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.17043144054427165, p=2.7078795259205508e-05, z-score=0.1721109773310937
#  - session 2: r=0.17994565369365928, p=9.215392164069816e-06, z-score=0.181926523080896
# Analyzing subject 102
# >> Subject 102: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.2518986889287094, p=3.885402028232906e-10, z-score=0.25743910879412313
#  - session 2: r=0.4650631070022135, p=1.5733218088355458e-33, z-score=0.5037524070251896
# Analyzing subject 103
# >> Subject 103: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.6653795784839649, p=5.795213420025537e-78, z-score=0.8024057660915899
#  - session 2: r=0.7583695637300177, p=3.042782160336385e-113, z-score=0.9923664191820216
# Analyzing subject 104
# >> Subject 104: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.05604707807021677, p=0.17034926533525374, z-score=0.056105875356776434
#  - session 2: r=0.25139676145543566, p=4.219709829092712e-10, z-score=0.25690324701395545
# Analyzing subject 105
# >> Subject 105: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.1777300566873255, p=1.1905378540158992e-05, z-score=0.1796377223500902
#  - session 2: r=0.4551444851115171, p=5.123706016436681e-32, z-score=0.49116991396931736
# Analyzing subject 106
# >> Subject 106: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.27865373097189133, p=3.6665527476407354e-12, z-score=0.2862218732817704
#  - session 2: r=0.4675725256220301, p=6.399681926065539e-34, z-score=0.5069591408660339
# Analyzing subject 107
# >> Subject 107: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.20694128257551608, p=3.155863789350529e-07, z-score=0.20997365446927116
#  - session 2: r=0.45015130489473654, p=2.8349452966863183e-31, z-score=0.48489001880149024
# Analyzing subject 108
# >> Subject 108: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.8509593678534798, p=2.254202630534501e-169, z-score=1.2596201965679912
#  - session 2: r=0.7532099369840883, p=7.051113413585417e-111, z-score=0.9803328042635328
# Analyzing subject 109
# >> Subject 109: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.4823603688131877, p=2.7358613472111264e-36, z-score=0.526055816337288
#  - session 2: r=0.11763297713983177, p=0.003908883540095678, z-score=0.1181801097347387
# Analyzing subject 110
# >> Subject 110: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.6219031196690792, p=1.656982465150321e-65, z-score=0.7281025220023524
#  - session 2: r=0.612785445451656, p=3.8712945001055917e-63, z-score=0.7133695547583676
# Analyzing subject 111
# >> Subject 111: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.6821462009034072, p=2.387565170324487e-83, z-score=0.8331171159159755
#  - session 2: r=0.4985871256370427, p=5.0219417266051956e-39, z-score=0.5474240823705671
# Analyzing subject 112
# >> Subject 112: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.340818863332818, p=8.74239574103944e-18, z-score=0.35501871782529026
#  - session 2: r=0.12323648941515024, p=0.0024953535068132308, z-score=0.12386611050425435
# Analyzing subject 113
# >> Subject 113: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.14886851437174548, p=0.0002528808671725908, z-score=0.14998310631175682
#  - session 2: r=0.4473338227136752, p=7.351520574513193e-31, z-score=0.4813621191790074
# Analyzing subject 114
# >> Subject 114: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.616534515692434, p=4.200926600136701e-64, z-score=0.7193951670501443
#  - session 2: r=0.47238384284416673, p=1.1169355761577026e-34, z-score=0.5131344919248828
# Analyzing subject 115
# >> Subject 115: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.5545480469490185, p=1.1193189061568344e-49, z-score=0.6249253728585354
#  - session 2: r=0.4405464786488564, p=7.039720612712454e-30, z-score=0.47290868354866133
# Analyzing subject 117
# >> Subject 117: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.646160247724512, p=3.3143975613888734e-72, z-score=0.7686782994444082
#  - session 2: r=0.26240956784222264, p=6.618919639489483e-11, z-score=0.2686944142901885
# Analyzing subject 118
# >> Subject 118: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.24518564013886798, p=1.1546592477919654e-09, z-score=0.2502840341459008
#  - session 2: r=0.40418200090492473, p=5.517836389354358e-25, z-score=0.4286374783371242
# Analyzing subject 119
# >> Subject 119: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.7549536642961429, p=1.1365522686743158e-111, z-score=0.9843752077281553
#  - session 2: r=0.320150061163651, p=9.115994943995328e-16, z-score=0.3318142980917319
# Analyzing subject 120
# >> Subject 120: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.28554486355221775, p=1.0128100914892993e-12, z-score=0.2937088602625257
#  - session 2: r=0.09808182541417959, p=0.016248239325608947, z-score=0.0983981705585161
# Analyzing subject 121
# >> Subject 121: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.08590154230096447, p=0.03540887616274664, z-score=0.08611377404765609
#  - session 2: r=0.398879611828112, p=2.5504619661352022e-24, z-score=0.42231584518585835
# Analyzing subject 122
# >> Subject 122: correlation between R_anterior_caudate and vmpfc:
#  - session 1: r=0.39561302330172804, p=6.460605324515808e-24, z-score=0.41843717913857414
#  - session 2: r=0.4782373356641345, p=1.286143404181361e-35, z-score=0.5206964245415298
# Analyzing connectivity between L_vlpfc and L_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.14449589110185143, p=0.00038423488292717886, z-score=0.14551432651014196
#  - session 2: r=0.2149460057734894, p=1.0586094535382956e-07, z-score=0.2183512086117088
# Analyzing subject 102
# >> Subject 102: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.31306242813570667, p=4.139458349157405e-15, z-score=0.3239370009544819
#  - session 2: r=0.5342618056547472, p=1.387450563593378e-45, z-score=0.5960904872203345
# Analyzing subject 103
# >> Subject 103: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.6172104237463893, p=2.8058864434113855e-64, z-score=0.7204862771785404
#  - session 2: r=0.5575671918781213, p=2.6029215152478704e-50, z-score=0.6292958918589205
# Analyzing subject 104
# >> Subject 104: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.22879668130769287, p=1.4445924732993558e-08, z-score=0.23291930753018864
#  - session 2: r=0.10080881825253685, p=0.013494380006479324, z-score=0.10115240279918213
# Analyzing subject 105
# >> Subject 105: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.26940033222495796, p=1.9514235038488017e-11, z-score=0.2762171144791452
#  - session 2: r=0.4416115914586742, p=4.954987924201323e-30, z-score=0.4742310673109597
# Analyzing subject 106
# >> Subject 106: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.434178311259319, p=5.60037727741058e-29, z-score=0.465034183895325
#  - session 2: r=0.6470736466715761, p=1.8038070562302278e-72, z-score=0.7702480202281571
# Analyzing subject 107
# >> Subject 107: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.2125196942915965, p=1.4807565171743636e-07, z-score=0.215808751815814
#  - session 2: r=0.29807805310948693, p=8.897059080285024e-14, z-score=0.307408908871983
# Analyzing subject 108
# >> Subject 108: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.3259367617320309, p=2.571562142285482e-16, z-score=0.3382752733863439
#  - session 2: r=0.5719890473588444, p=1.9859086650559049e-53, z-score=0.6504741100492277
# Analyzing subject 109
# >> Subject 109: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.26222243524266625, p=6.83555742044791e-11, z-score=0.2684934536517084
#  - session 2: r=0.43826896601310567, p=1.4854698456556203e-29, z-score=0.470086207201126
# Analyzing subject 110
# >> Subject 110: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.26834594281357005, p=2.3515124807524045e-11, z-score=0.27508056028545214
#  - session 2: r=0.4842481542610523, p=1.3373757438482643e-36, z-score=0.5285189494538972
# Analyzing subject 111
# >> Subject 111: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.691965651528762, p=1.1291588203001465e-86, z-score=0.8517174708395563
#  - session 2: r=0.6190746319049236, p=9.17128592557596e-65, z-score=0.7235032892367877
# Analyzing subject 112
# >> Subject 112: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.3476653921744142, p=1.733118232435632e-18, z-score=0.36278570139970034
#  - session 2: r=0.28546577228290787, p=1.0280843161106693e-12, z-score=0.29362274985046066
# Analyzing subject 113
# >> Subject 113: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.26037255683931837, p=9.385277770364621e-11, z-score=0.26650801601908586
#  - session 2: r=0.1225193657581652, p=0.0026455774346010145, z-score=0.12313799297848814
# Analyzing subject 114
# >> Subject 114: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.210856076836652, p=1.8596470398413938e-07, z-score=0.21406708680790765
#  - session 2: r=0.37792341551074304, p=8.305672208235845e-22, z-score=0.3976348310642228
# Analyzing subject 115
# >> Subject 115: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.4287661617940017, p=3.153411447321675e-28, z-score=0.45838393852971054
#  - session 2: r=0.32980402067539644, p=1.0870737710536045e-16, z-score=0.3426083407073424
# Analyzing subject 117
# >> Subject 117: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.7190622402649153, p=1.388612297536516e-96, z-score=0.9057005313916756
#  - session 2: r=0.6635736861451209, p=2.1002518172493574e-77, z-score=0.7991721216820606
# Analyzing subject 118
# >> Subject 118: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.19870209309868744, p=9.29335905308134e-07, z-score=0.20138093235006252
#  - session 2: r=0.40195160213031583, p=1.0541246432787598e-24, z-score=0.4259744314193547
# Analyzing subject 119
# >> Subject 119: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.7289373160268533, p=1.7136703718105515e-100, z-score=0.9264560651263637
#  - session 2: r=0.42370661832276535, p=1.5426657103869997e-27, z-score=0.45220108503625034
# Analyzing subject 120
# >> Subject 120: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.41855679907595267, p=7.553768100769093e-27, z-score=0.4459410023674099
#  - session 2: r=0.010543902376919018, p=0.796607272872499, z-score=0.010544293138487976
# Analyzing subject 121
# >> Subject 121: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.18690563485211098, p=4.038978432974891e-06, z-score=0.18912885974189184
#  - session 2: r=0.4160526830064144, p=1.6193412277088727e-26, z-score=0.44290885547148995
# Analyzing subject 122
# >> Subject 122: correlation between L_vlpfc and L_post_putamen:
#  - session 1: r=0.34688802662261514, p=2.0868973497773916e-18, z-score=0.36190172754877925
#  - session 2: r=0.26296110854306637, p=6.01865248796794e-11, z-score=0.2692868341025033
# Analyzing connectivity between R_vlpfc and R_post_putamen
# Analyzing subject 101
# >> Subject 101: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.6249748679938576, p=2.53292644197099e-66, z-score=0.7331272931932505
#  - session 2: r=0.6279631413440928, p=3.9930012974900973e-67, z-score=0.7380459870404968
# Analyzing subject 102
# >> Subject 102: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.49018300676899607, p=1.3687073493722214e-37, z-score=0.5363011951065729
#  - session 2: r=0.4487512625207007, p=4.556869713329441e-31, z-score=0.48313556481866
# Analyzing subject 103
# >> Subject 103: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.2022208659779226, p=5.891425453381567e-07, z-score=0.20504703110842776
#  - session 2: r=0.6702370555674061, p=1.735028305058476e-79, z-score=0.8111733993296825
# Analyzing subject 104
# >> Subject 104: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.4803954260843675, p=5.735723843849167e-36, z-score=0.5234982116690375
#  - session 2: r=0.468676406565276, p=4.2981430719853134e-34, z-score=0.5083728155030453
# Analyzing subject 105
# >> Subject 105: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.5473807716716665, p=3.366441405419071e-48, z-score=0.6146338696847634
#  - session 2: r=0.3854308063702002, p=1.0963261498635943e-22, z-score=0.40642244880282835
# Analyzing subject 106
# >> Subject 106: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.42649651089684126, p=6.449444453997585e-28, z-score=0.4556063521521879
#  - session 2: r=0.04841919930957814, p=0.23631620035288056, z-score=0.048457090918869565
# Analyzing subject 107
# >> Subject 107: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=-0.03599932710059881, p=0.37872588826255316, z-score=-0.03601489033184721
#  - session 2: r=0.224152056365343, p=2.858258900819061e-08, z-score=0.22802356617741243
# Analyzing subject 108
# >> Subject 108: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.6526330357797321, p=4.2489995196132375e-74, z-score=0.7798716596621758
#  - session 2: r=0.8168319719558985, p=5.3466356673516844e-145, z-score=1.1472228354934368
# Analyzing subject 109
# >> Subject 109: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.5801566827782305, p=2.9032143469787518e-55, z-score=0.6626988499891019
#  - session 2: r=0.5561997647657713, p=5.048763532093516e-50, z-score=0.6273137697397517
# Analyzing subject 110
# >> Subject 110: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.5698328398810661, p=5.941224083831827e-53, z-score=0.6472752718259217
#  - session 2: r=0.7622785585254631, p=4.4823387106609765e-115, z-score=1.0016316560052299
# Analyzing subject 111
# >> Subject 111: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.8329977285476393, p=7.444791374832955e-156, z-score=1.1978502974021081
#  - session 2: r=0.5715220679427743, p=2.5195868417543075e-53, z-score=0.6497803312376389
# Analyzing subject 112
# >> Subject 112: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.3879276670506432, p=5.52545082974677e-23, z-score=0.40935828000544067
#  - session 2: r=0.406698190144135, p=2.6427789277114484e-25, z-score=0.43164865220786214
# Analyzing subject 113
# >> Subject 113: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.0792085207168807, p=0.052476226842521276, z-score=0.07937479825040242
#  - session 2: r=0.2315091806850208, p=9.631797535917163e-09, z-score=0.23578352787260504
# Analyzing subject 114
# >> Subject 114: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.481363919869961, p=3.9846367759885435e-36, z-score=0.5247580334977857
#  - session 2: r=0.5381997443903498, p=2.340514394014578e-46, z-score=0.6016177820104605
# Analyzing subject 115
# >> Subject 115: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.7426287570671132, p=3.309432361891066e-106, z-score=0.956315232224532
#  - session 2: r=0.4879150849415701, p=3.2877265289173768e-37, z-score=0.5333203430908472
# Analyzing subject 117
# >> Subject 117: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.7635383283691486, p=1.1313909805063826e-115, z-score=1.0046456769443204
#  - session 2: r=0.5868716089233416, p=8.220921033937684e-57, z-score=0.6728806982883992
# Analyzing subject 118
# >> Subject 118: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.478243378187856, p=1.2832490067329784e-35, z-score=0.5207042588889187
#  - session 2: r=0.30708492874267096, p=1.4375258607114253e-14, z-score=0.31732362602090947
# Analyzing subject 119
# >> Subject 119: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.9098314987312555, p=1.3589938300159995e-230, z-score=1.5265450701948666
#  - session 2: r=0.34654712026740125, p=2.263645262443752e-18, z-score=0.36151424013379796
# Analyzing subject 120
# >> Subject 120: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.6606190194117182, p=1.6936431185111075e-76, z-score=0.7939112011035067
#  - session 2: r=-0.11617363664661659, p=0.004380443564987107, z-score=-0.11670054871660226
# Analyzing subject 121
# >> Subject 121: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.3264739153192349, p=2.283374760272024e-16, z-score=0.3388763919778518
#  - session 2: r=0.594032803751364, p=1.6739824081936062e-58, z-score=0.6838750398679532
# Analyzing subject 122
# >> Subject 122: correlation between R_vlpfc and R_post_putamen:
#  - session 1: r=0.41401305237338504, p=2.999365156636994e-26, z-score=0.4404447807876859
#  - session 2: r=0.4171218844077231, p=1.1702409539196166e-26, z-score=0.4442025757378425
# Analyzing connectivity between L_vlpfc and L_anterior_putamen
# Analyzing subject 101
# >> Subject 101: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.1497243463454118, p=0.00023268454971265027, z-score=0.15085844923335198
#  - session 2: r=-0.054354859066628174, p=0.18364241357867178, z-score=-0.054408483741529755
# Analyzing subject 102
# >> Subject 102: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.49167148674542976, p=7.673109874279581e-38, z-score=0.5382623275835269
#  - session 2: r=0.46497612549939427, p=1.6229330040545673e-33, z-score=0.5036414267979126
# Analyzing subject 103
# >> Subject 103: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.4013802665975545, p=1.2432604098495025e-24, z-score=0.4252931869156184
#  - session 2: r=0.4713330906713564, p=1.6391825284766002e-34, z-score=0.5117827803439381
# Analyzing subject 104
# >> Subject 104: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.23975303822700128, p=2.7237309749240524e-09, z-score=0.24451207292321128
#  - session 2: r=0.024360949140799542, p=0.55146721370267, z-score=0.024365769906666158
# Analyzing subject 105
# >> Subject 105: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.30532940220057614, p=2.0609867428084952e-14, z-score=0.3153864650876578
#  - session 2: r=0.29329291396915635, p=2.2839962189623013e-13, z-score=0.30216530839972044
# Analyzing subject 106
# >> Subject 106: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.23777641130860763, p=3.7029896371675337e-09, z-score=0.2424159480244129
#  - session 2: r=0.6197591657796138, p=6.071315758162788e-65, z-score=0.7246139639207299
# Analyzing subject 107
# >> Subject 107: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.18335516662147094, p=6.175880467511768e-06, z-score=0.185452382211211
#  - session 2: r=0.2645056491328305, p=4.6064488122785385e-11, z-score=0.27094683712078155
# Analyzing subject 108
# >> Subject 108: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.32209521051579537, p=5.975567660450497e-16, z-score=0.3339830941428137
#  - session 2: r=0.579201767703852, p=4.787433752231529e-55, z-score=0.6612606637238635
# Analyzing subject 109
# >> Subject 109: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.1936840689245297, p=1.7554749530745163e-06, z-score=0.19616201015274368
#  - session 2: r=0.3894589289877971, p=3.6191514607477627e-23, z-score=0.41116206247464726
# Analyzing subject 110
# >> Subject 110: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.25771703818819774, p=1.4730036438952925e-10, z-score=0.2636614807195993
#  - session 2: r=0.439334290779343, p=1.048266834158588e-29, z-score=0.4714055717180861
# Analyzing subject 111
# >> Subject 111: correlation between L_vlpfc and L_anterior_putamen:
#  - session 1: r=0.6851646086759455, p=2.343342090630065e-84, z-score=0.838784296804672
#  - session 2: r=0.6697167827149011, p=2.5345307230582098e-79, z-score=0.8102293896272503
# Analyzing subject 112
# >> Subject 112: correlation between L_vlpfc and L_anterior_putamen:
# ...
# Analyzing subject 104
# >> Subject 104: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.5644926688745697, p=8.660583652507313e-52, z-score=0.6394026236060469
#  - session 2: r=0.6884680165760766, p=1.7880211433641698e-85, z-score=0.8450374446280036
# Analyzing subject 105
# >> Subject 105: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.8309833226214255, p=1.9367002031187627e-154, z-score=1.191305521760464
#  - session 2: r=0.8965492464812558, p=1.1947973469873817e-213, z-score=1.454347819884167
# Analyzing subject 106
# >> Subject 106: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.6363211971456735, p=2.0419782195496952e-69, z-score=0.7519673801613718
#  - session 2: r=0.5397409508516757, p=1.1588522295223852e-46, z-score=0.6037899931147656
# Analyzing subject 107
# >> Subject 107: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.7792353283013161, p=1.8879915658611614e-123, z-score=1.0434208299534464
#  - session 2: r=0.7414816685617541, p=1.0289208517901645e-105, z-score=0.9537624787133885
# Analyzing subject 108
# >> Subject 108: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.935963668948913, p=2.791361706003843e-273, z-score=1.7044549533269637
#  - session 2: r=0.8719085503114229, p=1.3624948470871243e-187, z-score=1.340984672500839
# Analyzing subject 109
# >> Subject 109: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.7665782343293621, p=3.9385675061844935e-117, z-score=1.0119763916367077
#  - session 2: r=0.4981931549827118, p=5.875665231100986e-39, z-score=0.5468999114546852
# Analyzing subject 110
# >> Subject 110: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.7586987411784148, p=2.1397723648367713e-113, z-score=0.9931416367621785
#  - session 2: r=0.8569011977900928, p=3.0424909777249075e-174, z-score=1.281564519214177
# Analyzing subject 111
# >> Subject 111: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.8213180006611508, p=6.699716650674061e-148, z-score=1.1608540041267885
#  - session 2: r=0.8668216016268171, p=6.929214284902899e-183, z-score=1.3201515074515797
# Analyzing subject 112
# >> Subject 112: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.6386124443497567, p=4.672066773466973e-70, z-score=0.7558270741720619
#  - session 2: r=0.48357759482700424, p=1.7253965960703726e-36, z-score=0.527643349164838
# Analyzing subject 113
# >> Subject 113: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.5439243566975547, p=1.6879899735985523e-47, z-score=0.6097120287080592
#  - session 2: r=0.5422886619694609, p=3.5966687459987617e-47, z-score=0.6073920086101856
# Analyzing subject 114
# >> Subject 114: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.6853408351282678, p=2.0445537784603538e-84, z-score=0.839116530814369
#  - session 2: r=0.8127557444431541, p=1.980007394083764e-142, z-score=1.1350947665824265
# Analyzing subject 115
# >> Subject 115: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.8487417577701913, p=1.3072134133769536e-167, z-score=1.2516359831178938
#  - session 2: r=0.884028265281827, p=1.1459622210010018e-199, z-score=1.393910481317502
# Analyzing subject 117
# >> Subject 117: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.8956371675372035, p=1.4292830719412685e-212, z-score=1.449718348000171
#  - session 2: r=0.7965421813971733, p=8.363961933106722e-133, z-score=1.089080191119145
# Analyzing subject 118
# >> Subject 118: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.6957874739461114, p=5.274356126910848e-88, z-score=0.8590879711573342
#  - session 2: r=0.6487386189563638, p=5.918751182262153e-73, z-score=0.7731175897526612
# Analyzing subject 119
# >> Subject 119: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.5381567604715047, p=2.386728431282757e-46, z-score=0.6015572723158996
#  - session 2: r=0.44247603776267863, p=3.722763835446578e-30, z-score=0.47530545131954255
# Analyzing subject 120
# >> Subject 120: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.3976462954390183, p=3.6270120281164404e-24, z-score=0.42085003067677373
#  - session 2: r=0.45569494329207133, p=4.2356910375566994e-32, z-score=0.4918644170712461
# Analyzing subject 121
# >> Subject 121: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.7222478014648683, p=7.947866545444414e-98, z-score=0.9123281169589281
#  - session 2: r=0.803643946222795, p=6.565748718473823e-137, z-score=1.1088173499879328
# Analyzing subject 122
# >> Subject 122: correlation between R_anterior_caudate and L_anterior_caudate:
#  - session 1: r=0.6409231927019026, p=1.0422615072603844e-70, z-score=0.7597389856529159
#  - session 2: r=0.6834213525204871, p=8.98582840080905e-84, z-score=0.8355059094492221
#    subID  L_SMA_L_post_putamen  R_SMA_R_post_putamen  \
# 0    101              0.861705              0.999613
# 1    102              0.810701              0.758202
# 2    103              0.873777              1.096994
# 3    104              0.704080              0.628146
# 4    105              0.469796              0.380984
# 5    106              0.618276              0.622709
# 6    107              0.858922              0.734600
# 7    108              0.824334              0.966774
# 8    109              0.647729              0.743506
# 9    110              0.931577              0.925478
# 10   111              0.847096              0.956005
# 11   112              0.324343              0.422182
# 12   113              0.610986              0.492071
# 13   114              0.568433              0.787510
# 14   115              0.827587              0.700253
# 15   117              0.754052              1.126553
# 16   118              0.633084              0.663621
# 17   119              0.818500              1.352662
# 18   120              0.722101              0.407322
# 19   121              0.913063              1.000712
# 20   122              0.636676              0.705143
#
#     L_premotor_L_post_putamen  R_premotor_R_post_putamen  \
# 0                    0.803747                   1.094074
# 1                    0.819513                   0.931494
# 2                    0.954003                   1.029812
# 3                    0.550460                   0.607973
# 4                    0.473460                   0.496950
# 5                    0.640455                   0.393372
# 6                    0.914783                   0.825037
# 7                    0.975304                   1.107904
# 8                    0.621091                   0.890840
# 9                    0.894033                   1.148456
# 10                   1.038413                   1.441759
# 11                   0.370459                   0.553771
# 12                   0.613370                   0.428050
# 13                   0.670471                   0.802328
# 14                   0.795677                   0.882873
# 15                   1.163427                   1.248404
# 16                   0.551107                   0.662073
# 17                   1.116445                   1.588450
# 18                   0.757145                   1.061886
# 19                   0.900142                   1.015468
# 20                   0.566062                   0.766766
#
#     L_anterior_caudate_vmpfc  R_anterior_caudate_vmpfc  \
# 0                   0.164962                  0.177019
# 1                   0.487960                  0.380596
# 2                   0.856512                  0.897386
# 3                   0.235184                  0.156505
# 4                   0.423217                  0.335404
# 5                   0.399778                  0.396591
# 6                   0.282838                  0.347432
# 7                   0.941516                  1.119977
# 8                   0.323459                  0.322118
# 9                   0.589581                  0.720736
# 10                  0.690199                  0.690271
# 11                  0.225423                  0.239442
# 12                  0.279519                  0.315673
# 13                  0.472945                  0.616265
# 14                  0.586289                  0.548917
# 15                  0.668044                  0.518686
# 16                  0.388098                  0.339461
# 17                  0.718707                  0.658095
# 18                  0.288570                  0.196054
# 19                  0.151364                  0.254215
# 20                  0.462226                  0.469567
#
#     L_vlpfc_L_post_putamen  R_vlpfc_R_post_putamen  \
# 0                 0.181933                0.735587
# 1                 0.460014                0.509718
# 2                 0.674891                0.508110
# 3                 0.167036                0.515936
# 4                 0.375224                0.510528
# 5                 0.617641                0.252032
# 6                 0.261609                0.096004
# 7                 0.494375                0.963547
# 8                 0.369290                0.645006
# 9                 0.401800                0.824453
# 10                0.787610                0.923815
# 11                0.328204                0.420503
# 12                0.194823                0.157579
# 13                0.305851                0.563188
# 14                0.400496                0.744818
# 15                0.852436                0.838763
# 16                0.313678                0.419014
# 17                0.689329                0.944030
# 18                0.228243                0.338605
# 19                0.316019                0.511376
# 20                0.315594                0.442324
#
#     L_vlpfc_L_anterior_putamen  R_vlpfc_R_anterior_putamen  \
# 0                     0.048225                    0.502105
# 1                     0.520952                    0.652724
# 2                     0.468538                    0.633722
# 3                     0.134439                    0.407859
# 4                     0.308776                    0.358326
# 5                     0.483515                    0.408289
# 6                     0.228200                   -0.087966
# 7                     0.497622                    0.876070
# 8                     0.303662                    0.548014
# 9                     0.367534                    0.666387
# 10                    0.824507                    0.746319
# 11                    0.307940                    0.297204
# 12                    0.154343                    0.174367
# 13                    0.324551                    0.467885
# 14                    0.439025                    0.680766
# 15                    0.781691                    0.877791
# 16                    0.141879                    0.329732
# 17                    0.753408                    1.108253
# 18                    0.345340                    0.271557
# 19                    0.374621                    0.469134
# 20                    0.318681                    0.461498
#
#     L_vlpfc_L_anterior_caudate  R_vlpfc_R_anterior_caudate  \
# 0                     0.310097                    0.508337
# 1                     0.552395                    0.558526
# 2                     0.583724                    0.918458
# 3                     0.374569                    0.525065
# 4                     0.452012                    0.410962
# 5                     0.458778                    0.435492
# 6                     0.335756                    0.146385
# 7                     0.735241                    1.037964
# 8                     0.519355                    0.515260
# 9                     0.569057                    0.955317
# 10                    0.778061                    0.665807
# 11                    0.370630                    0.075391
# 12                    0.277225                    0.282417
# 13                    0.508794                    0.487102
# 14                    0.509729                    0.812016
# 15                    0.831413                    0.982835
# 16                    0.088357                    0.424936
# 17                    0.861155                    0.812827
# 18                    0.473988                    0.420228
# 19                    0.254611                    0.356300
# 20                    0.254065                    0.384563
#
#     R_frontopolar_R_anterior_caudate  R_frontopolar_R_post_putamen  \
# 0                           0.544146                      0.630043
# 1                           0.459935                      0.203949
# 2                           0.829468                      0.628293
# 3                           0.487885                      0.341469
# 4                           0.402510                      0.339243
# 5                           0.621021                      0.236597
# 6                           0.638945                      0.384664
# 7                           0.948543                      0.730018
# 8                           0.510092                      0.562172
# 9                           0.667636                      0.643407
# 10                          0.952395                      0.759289
# 11                          0.477411                      0.067324
# 12                          0.399503                      0.218889
# 13                          0.859675                      0.614055
# 14                          0.839327                      0.510868
# 15                          0.854376                      0.723513
# 16                          0.485402                      0.341059
# 17                          0.718488                      1.297183
# 18                          0.539899                      0.409013
# 19                          0.601306                      0.510313
# 20                          0.450973                      0.232312
#
#     R_post_putamen_L_post_putamen  R_anterior_caudate_L_anterior_caudate
# 0                        0.854171                               0.900072
# 1                        0.598096                               0.903952
# 2                        1.016094                               1.021193
# 3                        1.058985                               0.742220
# 4                        0.893498                               1.322827
# 5                        0.607455                               0.677879
# 6                        0.754974                               0.998592
# 7                        0.784545                               1.522720
# 8                        0.803852                               0.779438
# 9                        0.909383                               1.137353
# 10                       0.793669                               1.240503
# 11                       0.790492                               0.641735
# 12                       0.546597                               0.608552
# 13                       0.789055                               0.987106
# 14                       1.165961                               1.322773
# 15                       0.749037                               1.269399
# 16                       0.497515                               0.816103
# 17                       0.548608                               0.538431
# 18                       0.420960                               0.456357
# 19                       1.148692                               1.010573
# 20                       0.598148                               0.797622

# %%
connectivity_df
# show summary:
connectivity_df.describe()
# Out:
#        L_SMA_L_post_putamen  R_SMA_R_post_putamen  L_premotor_L_post_putamen  \
# count             21.000000             21.000000                  21.000000
# mean               0.726515              0.784335                   0.770932
# std                0.155917              0.256746                   0.216703
# min                0.324343              0.380984                   0.370459
# 25%                0.633084              0.628146                   0.613370
# 50%                0.754052              0.743506                   0.795677
# 75%                0.847096              0.966774                   0.914783
# max                0.931577              1.352662                   1.163427
#
#        R_premotor_R_post_putamen  L_anterior_caudate_vmpfc  \
# count                  21.000000                 21.000000
# mean                    0.903702                  0.458876
# std                     0.318235                  0.223155
# min                     0.393372                  0.151364
# 25%                     0.662073                  0.282838
# 50%                     0.890840                  0.423217
# 75%                     1.094074                  0.589581
# max                     1.588450                  0.941516
#
#        R_anterior_caudate_vmpfc  L_vlpfc_L_post_putamen  \
# count                 21.000000               21.000000
# mean                   0.461924                0.416005
# std                    0.249865                0.199812
# min                    0.156505                0.167036
# 25%                    0.315673                0.305851
# 50%                    0.380596                0.369290
# 75%                    0.616265                0.494375
# max                    1.119977                0.852436
#
#        R_vlpfc_R_post_putamen  L_vlpfc_L_anterior_putamen  \
# count               21.000000                   21.000000
# mean                 0.564997                    0.387021
# std                  0.249829                    0.209575
# min                  0.096004                    0.048225
# 25%                  0.420503                    0.303662
# 50%                  0.511376                    0.345340
# 75%                  0.744818                    0.483515
# max                  0.963547                    0.824507
#
#        R_vlpfc_R_anterior_putamen  L_vlpfc_L_anterior_caudate  \
# count                   21.000000                   21.000000
# mean                     0.516668                    0.480905
# std                      0.267145                    0.202522
# min                     -0.087966                    0.088357
# 25%                      0.358326                    0.335756
# 50%                      0.469134                    0.473988
# 75%                      0.666387                    0.569057
# max                      1.108253                    0.861155
#
#        R_vlpfc_R_anterior_caudate  R_frontopolar_R_anterior_caudate  \
# count                   21.000000                         21.000000
# mean                     0.557914                          0.632806
# std                      0.271339                          0.181973
# min                      0.075391                          0.399503
# 25%                      0.410962                          0.485402
# 50%                      0.508337                          0.601306
# 75%                      0.812016                          0.829468
# max                      1.037964                          0.952395
#
#        R_frontopolar_R_post_putamen  R_post_putamen_L_post_putamen  \
# count                     21.000000                      21.000000
# mean                       0.494461                       0.777609
# std                        0.270991                       0.208409
# min                        0.067324                       0.420960
# 25%                        0.339243                       0.598148
# 50%                        0.510313                       0.789055
# 75%                        0.630043                       0.893498
# max                        1.297183                       1.165961
#
#        R_anterior_caudate_L_anterior_caudate
# count                              21.000000
# mean                                0.937876
# std                                 0.287544
# min                                 0.456357
# 25%                                 0.742220
# 50%                                 0.903952
# 75%                                 1.137353
# max                                 1.522720
